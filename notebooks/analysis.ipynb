# %% [markdown]
# # NHANES Smoking and Hypertension Study
#
# This notebook explores the relationship between smoking and hypertension using NHANES data.

# %%
import pandas as pd
import numpy as np

print("Environment ready")
